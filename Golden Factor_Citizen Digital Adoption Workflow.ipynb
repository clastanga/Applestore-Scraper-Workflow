# %% [markdown]
# # AppScraper Workflow: From fetching the apps to scoring by subcategories
#
# #### this notebook uses the library AppStoreScraper taken from the repository https://github.com/digitalmethodsinitiative/itunes-app-scraper

# %% [markdown]
# ### Libraries

# %%
import pandas as pd

from urllib.parse import quote_plus
from itunes_app_scraper.util import AppStoreException, AppStoreCollections, AppStoreCategories, AppStoreMarkets

# for scraping app info from App Store
from itunes_app_scraper.scraper import AppStoreScraper

# for scraping app reviews from App Store
from app_store_scraper import AppStore

# for pretty printing data structures
from pprint import pprint

# for keeping track of timing
from datetime import datetime
#from tzlocal import get_localzone

# for building in wait times
import random
import time
import json
import os.path, time
import numpy as np
import requests
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')


from gspread_pandas import Spread
from gspread_pandas.conf import get_config as gspread_get_config
__google_key_path = Path.cwd() / 'swsp-missions.json'
print(gspread_get_config(file_name=__google_key_path)['client_email'])
# Out:
# mission-management@cellular-block-264708.iam.gserviceaccount.com

# %% [markdown]
# ### Connection with the spreadsheet

# %%
research_ui = Spread('1XrtpyON9eb13u6dZcgLL_WID3AVt-j8_ROaNHbCj2Dk')
# Set a new case_specific_ui everytime you work with a new subcategory!!!
case_specific_ui = Spread('1yEkcyHkSscmi6rwtFtMsheysU7H4eXmNx3jmANsPAIw') #Job
creative_ui = Spread('1pDI-aB-0tH4FA_OxycdgMONxqglVLGNXmhS_2JEwYYI')

ui_urls = {'research_ui' : research_ui.url,
           'creative_ui' : creative_ui.url,
           'case_specific_ui' : case_specific_ui.url}
ui_urls
# Out:
# {'research_ui': 'https://docs.google.com/spreadsheets/d/1XrtpyON9eb13u6dZcgLL_WID3AVt-j8_ROaNHbCj2Dk',
#  'creative_ui': 'https://docs.google.com/spreadsheets/d/1pDI-aB-0tH4FA_OxycdgMONxqglVLGNXmhS_2JEwYYI',
#  'case_specific_ui': 'https://docs.google.com/spreadsheets/d/1yEkcyHkSscmi6rwtFtMsheysU7H4eXmNx3jmANsPAIw'}

# %% [markdown]
# ### Folders: set the theme of the apps you want to scrape and name the collection folder accordingly to the project

# %%
theme = 'Job_apps'

# %%
path_folder = Path.cwd()
path_cache_folder = path_folder / f'{theme}_AppScraper'
path_applyzer_countries = path_folder / 'applyzer_countries.csv'
path_applyzer_markets_ios = path_folder / 'applyzer_markets_ios.csv'
path_results = path_folder / 'results'

if not path_cache_folder.exists():
    Path.mkdir(path_cache_folder)
    
if not path_results.exists():
    Path.mkdir(path_results)

# %% [markdown]
# ### Functions

# %%
def get_app_details(app_id, country, lang, flatten=True):
    try:
        app_id = int(app_id)
        id_field = "id"
    except ValueError:
        id_field = "bundleId"

    url = "https://itunes.apple.com/lookup?%s=%s&country=%s&entity=software" % (id_field, app_id, country)
    print(f'Getting data for {app_id} in {country}')

    try:
        result = requests.get(url).json()
    except Exception:
        try:
            # handle the retry here. 
            # Take an extra sleep as back off and then retry the URL once. 
            time.sleep(5)
            result = requests.get(url).json()
        except Exception:
            raise AppStoreException("Could not parse app store response for ID %s" % app_id)

    try:
        app = result["results"][0]
    except IndexError:
        app = dict(result)
            
        #raise AppStoreException("No app found with ID %s" % app_id)
    

    # 'flatten' app response
    # responses are at most two-dimensional (array within array), so simply
    # join any such values
    if flatten:
        for field in app:
            if isinstance(app[field], list):
                app[field] = ",".join(app[field])

    return app

def _log_error(app_store_country, message):
    """
    Write the error to a local file to capture the error. 
    :param str app_store_country: the country for the app store
    :param str message: the error message to log
    """
    app_log = "{0}_log.txt".format(app_store_country)
    errortime = datetime.now().strftime('%Y%m%d_%H:%M:%S - ')
    fh = open(app_log, "a")
    fh.write("%s %s \n" % (errortime,message))
    fh.close()
    
    
def get_multiple_app_details(app_ids, country, lang):
    """
    Get app details for a list of app IDs
    :param list app_id:  App IDs to retrieve details for
    :param str country:  Two-letter country code for the store to search in.
                         Defaults to 'nl'.
    :param str lang: Dummy argument for compatibility. Unused.
    :return generator:  A list (via a generator) of app details
    """
    for app_id in app_ids:
        try:
            time.sleep(1)
            yield get_app_details(app_id, country=country, lang=lang)
        except AppStoreException as ase:
            _log_error(country, str(ase))
            continue

# %%
def download_apps_country(app_name, country, search):
    scraper = AppStoreScraper()
    results = scraper.get_app_ids_for_query(app_name, num=search, country=country, lang='en')
    app_details = list(get_multiple_app_details(results, country, lang='en'))
    df_results = pd.DataFrame(app_details)
    path_cache_response = path_cache_folder / f'{country}_{app_name}_{search}.csv'
    with open(path_cache_response, 'w') as outfile:
        df_results.to_csv(path_cache_response, index=False)


def fetch_response(app_name, country_list, search):
    for country in country_list:
        path_cache_response = path_cache_folder / f'{country}_{app_name}_{search}.csv'
        if not path_cache_response.exists():
            download_apps_country(app_name, country, search)
            time.sleep(2)
            print("downloaded file for", path_cache_response.name)
        else:
            print("loaded file for", path_cache_response.name)

# %%
def construct_df(file):
    df_raw = pd.read_csv(file)
    df_raw['search_details'] = file.name.replace('.csv',"")
    df_raw['country'] = df_raw['search_details'].str[:2].str.upper()
    df_raw['search_details'] = df_raw['search_details'].str[3:]
    df_raw['downloaded_on'] = time.ctime(os.path.getctime(file))
    return df_raw

def final_df(folder):
    df = None

    for p in Path('.', folder).iterdir():
        print(p.name)
        if p.is_file():
            if df is None:
                df = construct_df(p)
            else:
                df = df.append(construct_df(p))
    return df

# %%
def df_results():
    df = None
    for p in Path('.', path_results).iterdir():
        if p.is_file():
            if df is None:
                df = pd.read_csv(p)
            else:
                df = df.append(pd.read_csv(p))
    return df.reset_index(drop=True)

# %% [markdown]
# ### Import Country selection from research_ui

# %%
df_countries = research_ui.sheet_to_df(index=False, sheet='OUTPUT - Countries_Selection')
df_country_ids = pd.read_csv(path_applyzer_countries)
df_countries = (
    df_countries.set_index('ISO2')
    .join(df_country_ids[['id', 'code']].set_index('code'))
    .reset_index()
)
print(f'There are {len(df_countries)} countries')
df_countries.head()
# Out:
# There are 57 countries
#   ISO2 Internal Country ISO3 population_2020 internet_penetration  \
# 0   AR        Argentina  ARG        45376763               74.29%
# 1   AU        Australia  AUS        25687041               86.55%
# 2   AT          Austria  AUT         8917205               87.75%
# 3   BE          Belgium  BEL        11555997               90.37%
# 4   BR           Brazil  BRA       212559409               70.43%
#
#   internet_users  id
# 0    33712623.81   2
# 1    22230862.18   3
# 2    7825043.993   4
# 3    10443213.78   5
# 4    149714694.7   6

# %% [markdown]
# ## Step 1:
# ### Fetching data by keywords with AppStoreScraper()

# %% [markdown]
# ### Set the keyword under the variable "app_name"

# %%
country_list = df_countries['ISO2'].str.lower()
search = 20
app_name = 'indeed'

# %%
fetch_response(app_name, country_list, search)
# Out:
# loaded file for ar_indeed_20.csv
# loaded file for au_indeed_20.csv
# loaded file for at_indeed_20.csv
# loaded file for be_indeed_20.csv
# loaded file for br_indeed_20.csv
# loaded file for bg_indeed_20.csv
# loaded file for ca_indeed_20.csv
# loaded file for cl_indeed_20.csv
# loaded file for cn_indeed_20.csv
# loaded file for co_indeed_20.csv
# loaded file for cz_indeed_20.csv
# loaded file for dk_indeed_20.csv
# loaded file for eg_indeed_20.csv
# loaded file for ee_indeed_20.csv
# loaded file for fi_indeed_20.csv
# loaded file for fr_indeed_20.csv
# loaded file for de_indeed_20.csv
# loaded file for gr_indeed_20.csv
# loaded file for hk_indeed_20.csv
# loaded file for hu_indeed_20.csv
# loaded file for in_indeed_20.csv
# loaded file for id_indeed_20.csv
# loaded file for ie_indeed_20.csv
# loaded file for il_indeed_20.csv
# loaded file for it_indeed_20.csv
# loaded file for jp_indeed_20.csv
# loaded file for ke_indeed_20.csv
# loaded file for lt_indeed_20.csv
# loaded file for my_indeed_20.csv
# loaded file for mx_indeed_20.csv
# loaded file for nl_indeed_20.csv
# loaded file for nz_indeed_20.csv
# loaded file for ng_indeed_20.csv
# loaded file for no_indeed_20.csv
# loaded file for pk_indeed_20.csv
# loaded file for ph_indeed_20.csv
# loaded file for pl_indeed_20.csv
# loaded file for pt_indeed_20.csv
# loaded file for qa_indeed_20.csv
# loaded file for ro_indeed_20.csv
# loaded file for ru_indeed_20.csv
# loaded file for sa_indeed_20.csv
# loaded file for sg_indeed_20.csv
# loaded file for sk_indeed_20.csv
# loaded file for za_indeed_20.csv
# loaded file for kr_indeed_20.csv
# loaded file for es_indeed_20.csv
# loaded file for se_indeed_20.csv
# loaded file for ch_indeed_20.csv
# loaded file for tw_indeed_20.csv
# loaded file for th_indeed_20.csv
# loaded file for tr_indeed_20.csv
# loaded file for ae_indeed_20.csv
# loaded file for gb_indeed_20.csv
# loaded file for us_indeed_20.csv
# loaded file for ua_indeed_20.csv
# loaded file for vn_indeed_20.csv

# %%
df_apps = final_df(path_cache_folder)
df_apps.to_csv(f'df_{theme}_apss_tot.csv', index=True)
# Out:
# ae_job search_100.csv
# gb_job search_100.csv
# ua_job search_100.csv
# us_job search_100.csv
# vn_job search_100.csv
# ar_job search_100.csv
# au_job search_100.csv
# at_job search_100.csv
# be_job search_100.csv
# br_job search_100.csv
# ca_job search_100.csv
# cl_job search_100.csv
# cn_job search_100.csv
# co_job search_100.csv
# cr_job search_100.csv
# hr_job search_100.csv
# cz_job search_100.csv
# dk_job search_100.csv
# de_job search_100.csv
# sv_job search_100.csv
# es_job search_100.csv
# fi_job search_100.csv
# fr_job search_100.csv
# gr_job search_100.csv
# gt_job search_100.csv
# hk_job search_100.csv
# hu_job search_100.csv
# in_job search_100.csv
# id_job search_100.csv
# ie_job search_100.csv
# il_job search_100.csv
# it_job search_100.csv
# kr_job search_100.csv
# kw_job search_100.csv
# lb_job search_100.csv
# lu_job search_100.csv
# my_job search_100.csv
# mx_job search_100.csv
# nl_job search_100.csv
# nz_job search_100.csv
# no_job search_100.csv
# pk_job search_100.csv
# pa_job search_100.csv
# pe_job search_100.csv
# ph_job search_100.csv
# pl_job search_100.csv
# pt_job search_100.csv
# qa_job search_100.csv
# ro_job search_100.csv
# ru_job search_100.csv
# sa_job search_100.csv
# ch_job search_100.csv
# sg_job search_100.csv
# sk_job search_100.csv
# si_job search_100.csv
# za_job search_100.csv
# lk_job search_100.csv
# se_job search_100.csv
# tw_job search_100.csv
# th_job search_100.csv
# tr_job search_100.csv
# bg_job search_100.csv
# eg_job search_100.csv
# ee_job search_100.csv
# jp_job search_100.csv
# ke_job search_100.csv
# lt_job search_100.csv
# ng_job search_100.csv
# ar_find a job_20.csv
# au_find a job_20.csv
# at_find a job_20.csv
# be_find a job_20.csv
# br_find a job_20.csv
# bg_find a job_20.csv
# ca_find a job_20.csv
# cl_find a job_20.csv
# cn_find a job_20.csv
# co_find a job_20.csv
# cz_find a job_20.csv
# dk_find a job_20.csv
# eg_find a job_20.csv
# ee_find a job_20.csv
# fi_find a job_20.csv
# fr_find a job_20.csv
# de_find a job_20.csv
# gr_find a job_20.csv
# hk_find a job_20.csv
# hu_find a job_20.csv
# in_find a job_20.csv
# id_find a job_20.csv
# ie_find a job_20.csv
# il_find a job_20.csv
# it_find a job_20.csv
# jp_find a job_20.csv
# ke_find a job_20.csv
# lt_find a job_20.csv
# my_find a job_20.csv
# mx_find a job_20.csv
# nl_find a job_20.csv
# nz_find a job_20.csv
# ng_find a job_20.csv
# no_find a job_20.csv
# pk_find a job_20.csv
# ph_find a job_20.csv
# pl_find a job_20.csv
# pt_find a job_20.csv
# qa_find a job_20.csv
# ro_find a job_20.csv
# ru_find a job_20.csv
# sa_find a job_20.csv
# sg_find a job_20.csv
# sk_find a job_20.csv
# za_find a job_20.csv
# kr_find a job_20.csv
# es_find a job_20.csv
# se_find a job_20.csv
# ch_find a job_20.csv
# tw_find a job_20.csv
# th_find a job_20.csv
# tr_find a job_20.csv
# ae_find a job_20.csv
# gb_find a job_20.csv
# us_find a job_20.csv
# ua_find a job_20.csv
# vn_find a job_20.csv
# ar_glassdoor_20.csv
# au_glassdoor_20.csv
# at_glassdoor_20.csv
# be_glassdoor_20.csv
# br_glassdoor_20.csv
# bg_glassdoor_20.csv
# ca_glassdoor_20.csv
# cl_glassdoor_20.csv
# cn_glassdoor_20.csv
# co_glassdoor_20.csv
# cz_glassdoor_20.csv
# dk_glassdoor_20.csv
# eg_glassdoor_20.csv
# ee_glassdoor_20.csv
# fi_glassdoor_20.csv
# fr_glassdoor_20.csv
# de_glassdoor_20.csv
# gr_glassdoor_20.csv
# hk_glassdoor_20.csv
# hu_glassdoor_20.csv
# in_glassdoor_20.csv
# id_glassdoor_20.csv
# ie_glassdoor_20.csv
# il_glassdoor_20.csv
# it_glassdoor_20.csv
# jp_glassdoor_20.csv
# ke_glassdoor_20.csv
# lt_glassdoor_20.csv
# my_glassdoor_20.csv
# mx_glassdoor_20.csv
# nl_glassdoor_20.csv
# nz_glassdoor_20.csv
# ng_glassdoor_20.csv
# no_glassdoor_20.csv
# pk_glassdoor_20.csv
# ph_glassdoor_20.csv
# pl_glassdoor_20.csv
# pt_glassdoor_20.csv
# qa_glassdoor_20.csv
# ro_glassdoor_20.csv
# ru_glassdoor_20.csv
# sa_glassdoor_20.csv
# sg_glassdoor_20.csv
# sk_glassdoor_20.csv
# za_glassdoor_20.csv
# kr_glassdoor_20.csv
# es_glassdoor_20.csv
# se_glassdoor_20.csv
# ch_glassdoor_20.csv
# tw_glassdoor_20.csv
# th_glassdoor_20.csv
# tr_glassdoor_20.csv
# ae_glassdoor_20.csv
# gb_glassdoor_20.csv
# us_glassdoor_20.csv
# ua_glassdoor_20.csv
# vn_glassdoor_20.csv
# ar_indeed_20.csv
# au_indeed_20.csv
# at_indeed_20.csv
# be_indeed_20.csv
# br_indeed_20.csv
# bg_indeed_20.csv
# ca_indeed_20.csv
# cl_indeed_20.csv
# cn_indeed_20.csv
# co_indeed_20.csv
# cz_indeed_20.csv
# dk_indeed_20.csv
# eg_indeed_20.csv
# ee_indeed_20.csv
# fi_indeed_20.csv
# fr_indeed_20.csv
# de_indeed_20.csv
# gr_indeed_20.csv
# hk_indeed_20.csv
# hu_indeed_20.csv
# in_indeed_20.csv
# id_indeed_20.csv
# ie_indeed_20.csv
# il_indeed_20.csv
# it_indeed_20.csv
# jp_indeed_20.csv
# ke_indeed_20.csv
# lt_indeed_20.csv
# my_indeed_20.csv
# mx_indeed_20.csv
# nl_indeed_20.csv
# nz_indeed_20.csv
# ng_indeed_20.csv
# no_indeed_20.csv
# pk_indeed_20.csv
# ph_indeed_20.csv
# pl_indeed_20.csv
# pt_indeed_20.csv
# qa_indeed_20.csv
# ro_indeed_20.csv
# ru_indeed_20.csv
# sa_indeed_20.csv
# sg_indeed_20.csv
# sk_indeed_20.csv
# za_indeed_20.csv
# kr_indeed_20.csv
# es_indeed_20.csv
# se_indeed_20.csv
# ch_indeed_20.csv
# tw_indeed_20.csv
# th_indeed_20.csv
# tr_indeed_20.csv
# ae_indeed_20.csv
# gb_indeed_20.csv
# us_indeed_20.csv
# ua_indeed_20.csv
# vn_indeed_20.csv

# %% [markdown]
# #### Keywords for the theme

# %%
list(set(df_apps['search_details'].tolist()))
# Out:
# ['find a job_20', 'glassdoor_20', 'indeed_20', 'job search_100']

# %% [markdown]
# ## Step 2
# ### Case specific:
# ### Importing the desired df_apps to normalise it and do some basic filtering

# %%
theme = theme
df_apps = pd.read_csv(f'df_{theme}_apss_tot.csv')

# %%
df_apps_tot = df_apps.copy()
df_apps_tot = df_apps_tot.reset_index()
df_apps_tot = df_apps_tot.dropna(subset = ["trackId"])
df_apps_tot = df_apps_tot.loc[df_apps_tot['price'] == 0.00]
df_apps_tot['ranking'] = df_apps_tot['Unnamed: 0'] + 1
df_apps_tot = df_apps_tot.drop(['Unnamed: 0'], axis=1)
df_apps_tot = df_apps_tot[['trackId', 'trackName', 'sellerName', 'country','ranking','trackViewUrl', 'search_details', 'primaryGenreName',
             'genres', 'genreIds', 'primaryGenreId', 'userRatingCount','averageUserRating']]
df_apps_tot['trackId'] = df_apps_tot['trackId'].astype(int)
df_apps_tot['primaryGenreId'] = df_apps_tot['primaryGenreId'].astype(int)
df_apps_tot['chart'] = 'free'

# %%
df_categories = (
    df_apps_tot[['primaryGenreId', 'primaryGenreName']]
    .groupby(['primaryGenreId', 'primaryGenreName'])
    .agg({'primaryGenreName':'count'})
    .rename(columns={'primaryGenreName':'counts'})
    .sort_values(by='counts', ascending=False)
    .reset_index()
)

df_categories_applyzer = pd.read_csv(path_applyzer_markets_ios)


df_categories = (
    df_categories.set_index('primaryGenreName')
    .join(df_apps_tot[['primaryGenreName', 'search_details', 'primaryGenreId']]
    .groupby(['search_details', 'primaryGenreName']).count()
    .unstack().transpose().droplevel(0)).reset_index()
    .rename(columns={'counts': 'tot_apps'})
)


df_categories = df_categories.fillna(0).set_index('primaryGenreName').astype(int)
case_specific_ui.df_to_sheet(df_categories, sheet=f'SOURCE - Categories Overview', index=True, replace=True)
df_categories
# Out:
#                    primaryGenreId  tot_apps  find a job_20  glassdoor_20  \
# primaryGenreName
# Business                     6000      7456            644           882
# Games                        6014       930            344             0
# Productivity                 6007       474             15             0
# Lifestyle                    6012       278             44            39
# Education                    6017       179             24             0
# Utilities                    6002       109             22             3
# Social Networking            6005        87              0            25
# Reference                    6006        69              0             0
# Photo & Video                6008        59             25             0
# Finance                      6015        30              0             0
# Medical                      6020        24              0             0
# Shopping                     6024        23              7             0
# Developer Tools              6026        14              0             0
# Travel                       6003         5              1             0
# Entertainment                6016         5              1             0
# Navigation                   6010         4              0             0
# Food & Drink                 6023         2              1             0
# News                         6009         1              0             0
# Music                        6011         1              0             0
# Health & Fitness             6013         1              0             0
#
#                    indeed_20  job search_100
# primaryGenreName
# Business                 952            4978
# Games                      7             579
# Productivity             103             356
# Lifestyle                 19             176
# Education                 10             145
# Utilities                 25              59
# Social Networking          1              61
# Reference                  3              66
# Photo & Video              0              34
# Finance                    1              29
# Medical                    0              24
# Shopping                   4              12
# Developer Tools            0              14
# Travel                     1               3
# Entertainment              1               3
# Navigation                 4               0
# Food & Drink               0               1
# News                       0               1
# Music                      1               0
# Health & Fitness           0               1

# %%
df_apps_normalized = (
    df_apps_tot.set_index('country').join(df_countries[['ISO2', 'id', 'Internal Country', 'internet_users',
       'internet_penetration']].set_index('ISO2'))
    .reset_index()
    .rename(columns={
        'index' : 'ISO2',
        'trackId' : 'app_id',
        'trackName' : 'name',
        'sellerName' : 'seller_name',
        'trackViewUrl' : 'url',
        'primaryGenreName' : 'cat_name',
        'id' : 'country_id',
        'primaryGenreId' : 'category_id'
        
    })
    [['app_id', 'ranking', 'chart', 'country_id', 'category_id', 'name',
       'seller_name', 'url', 'Internal Country',  'internet_users',
       'internet_penetration','cat_name', 'search_details']]
)


df_apps_normalized = df_apps_normalized.loc[df_apps_normalized['Internal Country'].isnull() != True][['app_id', 'ranking', 'chart', 'country_id', 'category_id', 'name',
       'seller_name', 'url', 'Internal Country',  'internet_users',
       'internet_penetration','cat_name', 'search_details']]

df_apps_normalized
# Out:
#           app_id  ranking chart  country_id  category_id  \
# 0      724241430        1  free        58.0         6000
# 1      309735670        2  free        58.0         6000
# 2      451816577        3  free        58.0         6002
# 3     1532042887        4  free        58.0         6000
# 4     1093457564        5  free        58.0         6000
# ...          ...      ...   ...         ...          ...
# 9746  1069568033       16  free        52.0         6000
# 9747  1040443949       17  free        52.0         6000
# 9748  1338484219       18  free        52.0         6000
# 9749  1155800838       19  free        52.0         6000
# 9750  1374123218       20  free        52.0         6000
#
#                                 name  \
# 0          Naukrigulf Job Search App
# 1                  Indeed Job Search
# 2                           UAE Jobs
# 3                          HiresGulf
# 4        GulfTalent - Job Search App
# ...                              ...
# 9746      hokify Job App - Find Jobs
# 9747           Reed.co.uk Job Search
# 9748   Jobs on map - easy job search
# 9749                  Make My Resume
# 9750  JobsDB Singapore job search sg
#
#                                             seller_name  \
# 0                                 Info Edge (India) Ltd
# 1                                           Indeed Inc.
# 2                              Muhammad Ameen Ameerzada
# 3     HORIZON INTERNATIONAL RECRUITMENT SERVICES - S...
# 4                                    Gulf Talent FZ-LLC
# ...                                                 ...
# 9746                                      JobSwipr GmbH
# 9747                                    Reed Online Ltd
# 9748                                  Andrei Sadovnicov
# 9749                                        Sagar Joshi
# 9750                                 Job Seeker Pty Ltd
#
#                                                     url Internal Country  \
# 0     https://apps.apple.com/ae/app/naukrigulf-job-s...              UAE
# 1     https://apps.apple.com/ae/app/indeed-job-searc...              UAE
# 2     https://apps.apple.com/ae/app/uae-jobs/id45181...              UAE
# 3     https://apps.apple.com/ae/app/hiresgulf/id1532...              UAE
# 4     https://apps.apple.com/ae/app/gulftalent-job-s...              UAE
# ...                                                 ...              ...
# 9746  https://apps.apple.com/za/app/hokify-job-app-f...     South Africa
# 9747  https://apps.apple.com/za/app/reed-co-uk-job-s...     South Africa
# 9748  https://apps.apple.com/za/app/jobs-on-map-easy...     South Africa
# 9749  https://apps.apple.com/za/app/make-my-resume/i...     South Africa
# 9750  https://apps.apple.com/za/app/jobsdb-singapore...     South Africa
#
#      internet_users internet_penetration   cat_name  search_details
# 0       9806331.398               99.15%   Business  job search_100
# 1       9806331.398               99.15%   Business  job search_100
# 2       9806331.398               99.15%  Utilities  job search_100
# 3       9806331.398               99.15%   Business  job search_100
# 4       9806331.398               99.15%   Business  job search_100
# ...             ...                  ...        ...             ...
# 9746    33312145.87               56.17%   Business       indeed_20
# 9747    33312145.87               56.17%   Business       indeed_20
# 9748    33312145.87               56.17%   Business       indeed_20
# 9749    33312145.87               56.17%   Business       indeed_20
# 9750    33312145.87               56.17%   Business       indeed_20
#
# [8695 rows x 13 columns]

# %%
df_appids_details = (
    df_apps_normalized.groupby(['cat_name','app_id',  'name'])
    .agg({'search_details': lambda x: ','.join(sorted(pd.Series.unique(x))), 
          'category_id': 'count', 
          'Internal Country':pd.Series.nunique,
         'url' : list})
    .sort_values(by=['cat_name', 'category_id'], ascending=[True, False])
    .rename(columns={'category_id': 'counts',
                    'Internal Country' : 'country_counts',
                    'url':'urls'})
    .reset_index()
)

print(f'There are {df_appids_details.app_id.nunique()} unique apps, over {len(df_appids_details)} entries')
case_specific_ui.df_to_sheet(df_appids_details, sheet=f'SOURCE - App_Details', index=False, replace=True)
#df_appids_details#.loc[(df_appids_details.cat_name == 'Graphics & Design')]
# Out:
# There are 626 unique apps, over 913 entries

# %% [markdown]
# ### Filtering (Case specific): Include column

# %%
df_exclude_select = case_specific_ui.sheet_to_df(sheet="OUTPUT - Exclude list", index=False)
exclude_cat_list = df_exclude_select['exclude_cat'].tolist()
exclude_names_list = df_exclude_select['exclude_names'].tolist()
include_names_list = df_exclude_select['include_names'].tolist()

# %%
exclude_cat_list
# Out:
# ['Games',
#  'Photo & Video',
#  'Travel',
#  'Entertainment',
#  'Navigation',
#  'Food & Drink',
#  'Music',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
exclude_names_list
# Out:
# ['Curriculum',
#  'CV',
#  'cvs',
#  'Cvs',
#  'Resume',
#  'resume',
#  'Builder',
#  'Lebenslauf',
#  'builder',
#  'templates',
#  '',
#  '']

# %%
include_names_list
# Out:
# ['job',
#  'search',
#  'find',
#  'hire',
#  'jobs',
#  'JOBS',
#  'Job',
#  'Jobs',
#  'Search',
#  'SEARCH',
#  'Find',
#  'Hire']

# %%
df_appids_details.loc[df_appids_details.cat_name.isin(exclude_cat_list), 'Include'] = 'False'
print(f"False = {len(df_appids_details.loc[(df_appids_details['Include'] == 'False')])}")
# Out:
# False = 124

# %%
df_false = df_appids_details.loc[df_appids_details['Include'] == 'False']
df_examine = df_appids_details.loc[df_appids_details['Include'] != 'False']

# %%
df_examine.loc[(df_examine['name'].str.contains('job', case=False))
               | (df_examine['name'].str.contains('search', case=False))
               | (df_examine['name'].str.contains('find', case=False))
               | (df_examine['name'].str.contains('hire', case=False))
               | (df_examine['name'].str.contains('jobs', case=False)), 'Include'] = 'True'

df_examine.loc[(df_examine['Include'] != 'False') 
                      & (df_examine['name'].str.contains('CV', case=False))
                      | (df_examine['name'].str.contains('Cvs', case=False))
                      | (df_examine['name'].str.contains('Resume', case=False))
                      | (df_examine['name'].str.contains('builder', case=False))
                      | (df_examine['name'].str.contains('Lebenslauf', case=False)), 'Include'] = 'False'



print(f"True = {len(df_examine.loc[(df_examine['Include'] == 'True')])}, False = {len(df_examine.loc[(df_examine['Include'] == 'False')])}")
df_include = df_examine.append(df_false)
print(f"True = {len(df_include.loc[(df_include['Include'] == 'True')])}, False = {len(df_include.loc[(df_include['Include'] == 'False')])}")
df_include
# Out:
# True = 321, False = 84
# True = 321, False = 208
#           cat_name      app_id                            name  \
# 0         Business   981163277      JOB TODAY: Easy Job Search
# 1         Business  1040443949           Reed.co.uk Job Search
# 2         Business   589698942    Glassdoor - Job Search Tools
# 3         Business   309735670               Indeed Job Search
# 4         Business   288429040     LinkedIn: Job Search & News
# ..             ...         ...                             ...
# 775  Photo & Video  1361012099  Facelab: Gezicht Foto Bewerken
# 883         Travel  1492085245   Rida — cheaper than taxi ride
# 884         Travel   475966832                   同程旅行-订酒店机票火车票
# 885         Travel   520472426           MyWheels - Auto huren
# 886         Travel  1071794769  Quick Ride Carpool,Taxi & Bike
#
#                                         search_details  counts  \
# 0    find a job_20,glassdoor_20,indeed_20,job searc...     157
# 1    find a job_20,glassdoor_20,indeed_20,job searc...     132
# 2    find a job_20,glassdoor_20,indeed_20,job searc...     130
# 3    find a job_20,glassdoor_20,indeed_20,job searc...     128
# 4    find a job_20,glassdoor_20,indeed_20,job searc...     127
# ..                                                 ...     ...
# 775                                     job search_100       1
# 883                       find a job_20,job search_100       2
# 884                                     job search_100       1
# 885                                          indeed_20       1
# 886                                     job search_100       1
#
#      country_counts                                               urls Include
# 0                50  [https://apps.apple.com/ae/app/job-today-easy-...    True
# 1                57  [https://apps.apple.com/ae/app/reed-co-uk-job-...    True
# 2                33  [https://apps.apple.com/ae/app/glassdoor-job-s...    True
# 3                32  [https://apps.apple.com/ae/app/indeed-job-sear...    True
# 4                34  [https://apps.apple.com/ae/app/linkedin-job-se...    True
# ..              ...                                                ...     ...
# 775               1  [https://apps.apple.com/nl/app/facelab-gezicht...   False
# 883               1  [https://apps.apple.com/ng/app/rida-cheaper-th...   False
# 884               1  [https://apps.apple.com/hk/app/%E5%90%8C%E7%A8...   False
# 885               1  [https://apps.apple.com/nl/app/mywheels-auto-h...   False
# 886               1  [https://apps.apple.com/in/app/quick-ride-carp...   False
#
# [913 rows x 8 columns]

# %% [markdown]
# ### Preparing for DC

# %%
df_appids_filt = df_include.copy().set_index('app_id')
case_specific_ui.df_to_sheet(df_appids_filt, sheet= 'SOURCE - Apps Overview', index=True, replace=True)
case_specific_ui.df_to_sheet(df_apps_normalized[['app_id', 'ranking', 'name', 'seller_name', 'url', 'Internal Country']], sheet= 'SOURCE - Apps Tot', index=False, replace=True)

# %% [markdown]
# ### Import the DC and output a .csv with the included apps

# %%
df_appids_dc = case_specific_ui.sheet_to_df(sheet="OUTPUT - Apps DC", index=True).reset_index()
df_appids_dc['app_id'] = df_appids_dc.app_id.astype(int)
df_appids_dc['Include'] = df_appids_dc['Include'].replace(r'^\s*$', np.nan, regex=True).str.capitalize()

df_apps_normalized_filt = df_apps_normalized.set_index('app_id').join(df_appids_dc[['app_id','Include', 'SubCat']].set_index('app_id')).sort_values(by='ranking').reset_index()#.drop_duplicates()
print(f"True = {len(df_apps_normalized_filt.loc[(df_apps_normalized_filt['Include'] == 'True')])}, False = {len(df_apps_normalized_filt.loc[(df_apps_normalized_filt['Include'] == 'False')])}, Empty = {len(df_apps_normalized_filt.loc[(df_apps_normalized_filt['Include'].isnull() == True)])}")
print("The included categories are:")
print(df_apps_normalized_filt.loc[df_apps_normalized_filt['Include'] != 'False']['cat_name'].value_counts())

results = path_results / f'df_{theme}_filtered.csv'
with open(results, 'w') as outfile:
    df_apps_normalized_filt.loc[df_apps_normalized_filt['Include'] != 'False'].to_csv(results, index=False)
# Out:
# True = 6547, False = 1684, Empty = 464
# The included categories are:
# Business             6365
# Lifestyle             181
# Education             112
# Productivity          100
# Social Networking      74
# Utilities              61
# Reference              53
# Finance                23
# Medical                18
# Shopping               11
# Developer Tools        11
# News                    1
# Health & Fitness        1
# Name: cat_name, dtype: int64

# %%
df_country_view_50 = (
    df_apps_normalized_filt.loc[(df_apps_normalized_filt['Include'] != 'False') & 
                                (df_apps_normalized_filt['ranking'] <= 50)]
    [['Internal Country', 'app_id']]
    .groupby('Internal Country').count()
    .sort_values(by='app_id', ascending=False)
    .rename(columns={'app_id':'ranking_below_50'})
)

df_country_view = (
    df_apps_normalized_filt.loc[(df_apps_normalized_filt['Include'] != 'False')]
    [['Internal Country', 'app_id']]
    .groupby('Internal Country').count()
    .sort_values(by='app_id', ascending=False)
    .rename(columns={'app_id':'apps_count'}))


df_country_view.join(df_country_view_50)
# Out:
#                   apps_count  ranking_below_50
# Internal Country
# Austria                  141                98
# Singapore                139                94
# UK                       139                96
# USA                      138                96
# Kenya                    137                91
# Norway                   137                92
# Australia                136                92
# Bulgaria                 134                93
# Canada                   134                92
# UAE                      134                90
# Ireland                  134                90
# Argentina                133                88
# Nigeria                  133                89
# Greece                   132                91
# Indonesia                132                88
# Egypt                    131                87
# Qatar                    131                88
# Romania                  130                88
# New Zealand              130                87
# Czechia                  129                88
# Portugal                 129                84
# Pakistan                 129                87
# Finland                  128                88
# Lithuania                128                88
# South Africa             127                85
# Philippines              126                86
# Spain                    126                84
# Sweden                   126                84
# Malaysia                 126                86
# Denmark                  126                87
# France                   124                81
# Hungary                  124                84
# Slovakia                 123                82
# Taiwan                   123                80
# Thailand                 122                78
# Colombia                 122                77
# Turkey                   122                79
# Israel                   122                81
# Belgium                  122                78
# India                    121                88
# Netherlands              121                76
# Poland                   121                77
# Switzerland              121                80
# Ukraine                  120                76
# Chile                    118                75
# Germany                  116                74
# Italy                    116                78
# China                    115                78
# Estonia                  114                72
# Brazil                   107                69
# Mexico                   107                64
# Vietnam                  107                68
# South Korea              102                63
# Saudi Arabia              89                46
# Hong Kong                 87                66
# Japan                     87                57
# Russia                    83                52

# %% [markdown]
# ## Step 3
# ### Scoring:
# ### Importing all the DC from the research_ui and the existing apps dataframes

# %%
df_categories_ios = pd.read_csv(path_applyzer_markets_ios)
df_applyzer_ranking_all = pd.read_csv('df_applyzer_ranking_all.csv')
df_applyzer_apps_all = pd.read_csv('df_applyzer_apps_all.csv', index_col=0)
df_appscraper_all = df_results()

# %% [markdown]
# #### Creating a df with Applyzer apps and appending the new df from Appscraper

# %%
df_charts_ww = (
    pd.merge(df_applyzer_ranking_all, df_applyzer_apps_all, how='left', left_on='app_id', right_index=True)
    .set_index(['app_id'])
    .join(df_countries[['Internal Country', 'id', 'internet_users', 'internet_penetration']].set_index('id'), on='country_id')
    .join(df_categories_ios.rename(columns={'name':'cat_name'}).set_index('id'), on='category_id')
    .reset_index()
)
df_charts_ww

df_charts_ww_free = (
    pd
    .merge(df_applyzer_ranking_all[df_applyzer_ranking_all.chart == 'free'], 
             df_applyzer_apps_all, 
             how='left', left_on='app_id', right_index=True)
    .drop(columns=['chart'])
    .set_index(['app_id'])
    .join(df_countries[['Internal Country', 'id', 'internet_users', 'internet_penetration']].set_index('id'), on='country_id')
    .join(df_categories_ios.rename(columns={'name':'cat_name'}).set_index('id'), on='category_id')
    .reset_index()
)
df_charts_ww_free['ranking'] = df_charts_ww_free['ranking'] + 1
df_charts_ww_free.head()
# Out:
#        app_id  ranking  country_id  category_id  \
# 0  1527399597        1           2            4
# 1   924620788        2           2            4
# 2   570060128        3           2            4
# 3  1208138685        4           2            4
# 4   919087726        5           2            4
#
#                              name       seller_name  \
# 0       PlantIn: Plant Identifier  Vortemol Limited
# 1                Google Classroom        Google LLC
# 2     Duolingo - Language Lessons     Duolingo, Inc
# 3  Toca Life World: Build stories      Toca Boca AB
# 4                       Photomath   Photomath, Inc.
#
#                                          url Internal Country internet_users  \
# 0  https://itunes.apple.com/app/id1527399597        Argentina    33712623.81
# 1   https://itunes.apple.com/app/id924620788        Argentina    33712623.81
# 2   https://itunes.apple.com/app/id570060128        Argentina    33712623.81
# 3  https://itunes.apple.com/app/id1208138685        Argentina    33712623.81
# 4   https://itunes.apple.com/app/id919087726        Argentina    33712623.81
#
#   internet_penetration   cat_name
# 0               74.29%  Education
# 1               74.29%  Education
# 2               74.29%  Education
# 3               74.29%  Education
# 4               74.29%  Education

# %% [markdown]
# #### Introducing SubCategories and appending new dataframes

# %%
df_app_dc = research_ui.sheet_to_df(sheet="OUTPUT - Applyzer App DC", index=False)
df_app_dc['app_id'] = df_app_dc.app_id.astype(int)
df_app_dc.SubCat = df_app_dc.SubCat.replace(r'^\s*$', np.nan, regex=True)
df_app_dc = pd.merge(df_app_dc, df_countries, left_on='origin country', right_on='Internal Country', how='left')
df_app_dc = df_app_dc[['app_id', 'id', 'Internal Country', 'SubCat']].rename(columns={'id':'origin_id', 'Internal Country':'Origin Country'})

df_charts_ww_free = pd.merge(df_charts_ww_free, df_app_dc, left_on='app_id', right_on='app_id', how='left')


df_charts_ww_free = df_charts_ww_free.append(df_appscraper_all[['app_id', 'ranking', 'country_id', 'category_id', 'name',
       'seller_name', 'url', 'Internal Country', 'internet_users',
       'internet_penetration', 'cat_name', 'SubCat']]).reset_index(drop=True)

df_charts_ww_free.head()
# Out:
#        app_id  ranking  country_id  category_id  \
# 0  1527399597        1         2.0            4
# 1   924620788        2         2.0            4
# 2   570060128        3         2.0            4
# 3  1208138685        4         2.0            4
# 4   919087726        5         2.0            4
#
#                              name       seller_name  \
# 0       PlantIn: Plant Identifier  Vortemol Limited
# 1                Google Classroom        Google LLC
# 2     Duolingo - Language Lessons     Duolingo, Inc
# 3  Toca Life World: Build stories      Toca Boca AB
# 4                       Photomath   Photomath, Inc.
#
#                                          url Internal Country internet_users  \
# 0  https://itunes.apple.com/app/id1527399597        Argentina    33712623.81
# 1   https://itunes.apple.com/app/id924620788        Argentina    33712623.81
# 2   https://itunes.apple.com/app/id570060128        Argentina    33712623.81
# 3  https://itunes.apple.com/app/id1208138685        Argentina    33712623.81
# 4   https://itunes.apple.com/app/id919087726        Argentina    33712623.81
#
#   internet_penetration   cat_name  origin_id Origin Country           SubCat
# 0               74.29%  Education        NaN            NaN        Reference
# 1               74.29%  Education        1.0            USA   Study Platform
# 2               74.29%  Education        1.0            USA  Online Learning
# 3               74.29%  Education       54.0         Sweden      Edutainment
# 4               74.29%  Education        1.0            USA   Learning Tools

# %% [markdown]
# #### Scoring

# %%
df_charts_ww_free_total = df_charts_ww_free[df_charts_ww_free.category_id == 99].copy()
df_charts_ww_free_total['score_ranking'] = 100 * (0.985 ** df_charts_ww_free_total['ranking'])
df_charts_ww_free_total['score_ranking_adj'] = df_charts_ww_free_total['score_ranking'].astype(float) * df_charts_ww_free_total['internet_users'].astype(float)
df_charts_ww_free_cat = df_charts_ww_free[df_charts_ww_free.category_id != 99].copy()
df_charts_ww_free_total['ranking_overall'] = df_charts_ww_free_total['ranking']
df_charts_ww_free_cat.app_id = df_charts_ww_free_cat.app_id.astype("int64")

df_charts_ww_free_cat = pd.merge(
    df_charts_ww_free_cat,
    df_charts_ww_free_total[['country_id', 'app_id','score_ranking','score_ranking_adj', 'ranking_overall']],
    left_on=['country_id', 'app_id'],
    right_on=['country_id', 'app_id'],
    how='left'
)

df_country_count = df_charts_ww_free_cat[df_charts_ww_free_cat.ranking <= 50].groupby(['app_id'])[['country_id']].agg('count').sort_values('country_id', ascending=False)
df_country_count['unique_score'] = 1 / (1.04 ** df_country_count.country_id)
df_country_count = df_country_count.reset_index()


df_charts_ww_final = pd.merge(df_charts_ww_free_cat, df_country_count[['app_id', 'unique_score']], left_on='app_id', right_on='app_id', how='left')
df_charts_ww_final.loc[df_charts_ww_final.origin_id == df_charts_ww_final.country_id, 'unique_score'] = 1 / (1.04)
df_charts_ww_final
# Out:
#             app_id  ranking  country_id  category_id  \
# 0       1527399597        1         2.0            4
# 1        924620788        2         2.0            4
# 2        570060128        3         2.0            4
# 3       1208138685        4         2.0            4
# 4        919087726        5         2.0            4
# ...            ...      ...         ...          ...
# 695629  1512048310       20        10.0         6015
# 695630  1205990992       20        62.0         6015
# 695631  1509163188       20        48.0         6015
# 695632  1506274532       20        34.0         6015
# 695633  1334540709       20        34.0         6009
#
#                                   name             seller_name  \
# 0            PlantIn: Plant Identifier        Vortemol Limited
# 1                     Google Classroom              Google LLC
# 2          Duolingo - Language Lessons           Duolingo, Inc
# 3       Toca Life World: Build stories            Toca Boca AB
# 4                            Photomath         Photomath, Inc.
# ...                                ...                     ...
# 695629        Crypto.com l DeFi Wallet               DeFi Labs
# 695630  TradingView - FX、株価チャート・ビットコイン       TradingView, Inc.
# 695631                       VC Wallet  BLOCK CHAIN JAPAN K.K.
# 695632   BlockFi: Buy and Trade Crypto           BlockFi, Inc.
# 695633                 BLOCKCHAIN INFO        Алексей Веселков
#
#                                                       url Internal Country  \
# 0               https://itunes.apple.com/app/id1527399597        Argentina
# 1                https://itunes.apple.com/app/id924620788        Argentina
# 2                https://itunes.apple.com/app/id570060128        Argentina
# 3               https://itunes.apple.com/app/id1208138685        Argentina
# 4                https://itunes.apple.com/app/id919087726        Argentina
# ...                                                   ...              ...
# 695629  https://apps.apple.com/co/app/crypto-com-l-def...         Colombia
# 695630  https://apps.apple.com/jp/app/tradingview-fx-%...            Japan
# 695631  https://apps.apple.com/ch/app/vc-wallet/id1509...      Switzerland
# 695632  https://apps.apple.com/mx/app/blockfi-buy-and-...           Mexico
# 695633  https://apps.apple.com/mx/app/blockchain-info/...           Mexico
#
#        internet_users internet_penetration   cat_name  origin_id  \
# 0         33712623.81               74.29%  Education        NaN
# 1         33712623.81               74.29%  Education        1.0
# 2         33712623.81               74.29%  Education        1.0
# 3         33712623.81               74.29%  Education       54.0
# 4         33712623.81               74.29%  Education        1.0
# ...               ...                  ...        ...        ...
# 695629    33077385.89               65.01%    Finance        NaN
# 695630    114865144.0               91.28%    Finance        NaN
# 695631    8044930.658               93.15%    Finance        NaN
# 695632    90343064.59               70.07%    Finance        NaN
# 695633    90343064.59               70.07%       News        NaN
#
#        Origin Country           SubCat  score_ranking  score_ranking_adj  \
# 0                 NaN        Reference      51.427349       1.733751e+09
# 1                 USA   Study Platform      48.410444       1.632043e+09
# 2                 USA  Online Learning      26.850480       9.052001e+08
# 3              Sweden      Edutainment      22.396844       7.550564e+08
# 4                 USA   Learning Tools      20.148394       6.792552e+08
# ...               ...              ...            ...                ...
# 695629            NaN   Cryptocurrency            NaN                NaN
# 695630            NaN   Cryptocurrency            NaN                NaN
# 695631            NaN   Cryptocurrency            NaN                NaN
# 695632            NaN   Cryptocurrency            NaN                NaN
# 695633            NaN   Cryptocurrency            NaN                NaN
#
#         ranking_overall  unique_score
# 0                  44.0      0.390121
# 1                  48.0      0.164614
# 2                  87.0      0.111207
# 3                  99.0      0.140713
# 4                 106.0      0.120282
# ...                 ...           ...
# 695629              NaN      0.513373
# 695630              NaN      0.050754
# 695631              NaN      0.888996
# 695632              NaN      0.924556
# 695633              NaN      0.164614
#
# [695634 rows x 18 columns]

# %% [markdown]
# ## Step 4
# ### Grouping and Scoring the apps, by Subcategories

# %% [markdown]
# #### SubCategories Overview

# %%
df_sub_cat = (
    df_charts_ww_final[['SubCat','cat_name','app_id']]
    .groupby('SubCat').agg({'app_id':'count', 'cat_name':lambda x: ', '.join(sorted(pd.Series.unique(x)))})
    .sort_values(by='app_id', ascending=False)
    .rename(columns={'app_id':'counts',
                    'cat_name': 'cat_list'})
)
df_sub_cat['cat_list'] = df_sub_cat['cat_list'].astype(str)
df_sub_cat['cat_list'] = df_sub_cat['cat_list'].str.strip('{}')

creative_ui.df_to_sheet(df_sub_cat, sheet='SOURCE - Available SubCat', index=True)
df_sub_cat
# Out:
#                         counts  \
# SubCat
# Health Self Management    7776
# Job Search                7011
# Productivity              6092
# Travel Booking            5156
# Maps                      4918
# Cryptocurrency            4034
# Government/COVID          3031
# Delivery Service          2796
# Personal Transport        2723
# Patient Platform          1657
# Service Provider          1539
# Edutainment               1242
# Travel Tools              1153
# Parking                    994
# Online Learning            898
# Reference                  822
# Study Platform             775
# Learning Tools             457
# Telemedicine               326
# Restaurant Order           284
# Pharmacy                   279
# Health Reference           235
# Clinic                     218
# eGov                       203
# Payments                   126
# Excercise Locations        117
# Consumer Deals             111
# Student Platform           109
# Consumer Offers            105
# -                           17
# HR                           4
# Classroom                    2
# Emergency                    1
#
#                                                                  cat_list
# SubCat
# Health Self Management  Education, Healthcare/Fitness, Medical, Naviga...
# Job Search              Business, Developer Tools, Education, Finance,...
# Productivity            Education, Healthcare/Fitness, Medical, Naviga...
# Travel Booking                                         Navigation, Travel
# Maps                                                   Navigation, Travel
# Cryptocurrency          Business, Education, Entertainment, Finance, L...
# Government/COVID        Healthcare/Fitness, Medical, Navigation, Trave...
# Delivery Service              Food & Drink, Navigation, Travel, Utilities
# Personal Transport                 Healthcare/Fitness, Navigation, Travel
# Patient Platform                   Healthcare/Fitness, Medical, Utilities
# Service Provider        Finance, Healthcare/Fitness, Medical, Navigati...
# Edutainment                        Education, Healthcare/Fitness, Medical
# Travel Tools            Healthcare/Fitness, Navigation, Travel, Utilities
# Parking                                     Navigation, Travel, Utilities
# Online Learning                                                 Education
# Reference                                      Education, Medical, Travel
# Study Platform                                                  Education
# Learning Tools                                                  Education
# Telemedicine                                  Healthcare/Fitness, Medical
# Restaurant Order                                             Food & Drink
# Pharmacy                                      Healthcare/Fitness, Medical
# Health Reference                              Healthcare/Fitness, Medical
# Clinic                                        Healthcare/Fitness, Medical
# eGov                                Healthcare/Fitness, Travel, Utilities
# Payments                             Finance, Medical, Navigation, Travel
# Excercise Locations                        Healthcare/Fitness, Navigation
# Consumer Deals          Finance, Food & Drink, Medical, Navigation, Tr...
# Student Platform                                                Education
# Consumer Offers                       Education, Food & Drink, Navigation
# -                                                               Education
# HR                                                  Finance, Food & Drink
# Classroom                                                       Education
# Emergency                                                         Medical

# %% [markdown]
# #### Ranking score by Category and SubCategory

# %%
df_ranking_score = df_charts_ww_final.copy()
df_ranking_score = (
    df_ranking_score
    [['Internal Country','cat_name', 'SubCat','internet_penetration', 'unique_score', 'score_ranking','app_id']]
)

df_ranking_score['internet_penetration'] = df_ranking_score['internet_penetration'].str.replace('%','')
df_ranking_score['internet_penetration'] = df_ranking_score['internet_penetration'].replace(r'^\s*$', 0, regex=True).astype(float)
df_ranking_score = df_ranking_score.fillna(0)
df_ranking_score['final_score'] = df_ranking_score['score_ranking'] * df_ranking_score['internet_penetration']/ 100
df_ranking_score = df_ranking_score[df_ranking_score.final_score != 0]
df_ranking_score.SubCat = df_ranking_score.SubCat.replace(0, np.nan)

df_cat_scores = df_ranking_score.groupby(['Internal Country', 'cat_name']).agg('sum')[['final_score']].sort_values('final_score', ascending=False).unstack()#.droplevel(0, axis=1)
#df_cat_scores.sort_values(by=('Business'), ascending=False)

df_subcat_scores = df_ranking_score.groupby(['Internal Country', 'SubCat']).agg('sum')[['final_score']].sort_values('final_score', ascending=False).unstack()#.droplevel(0, axis=1)
#df_subcat_scores

# %%
cat_score = df_cat_scores.transpose().droplevel(0)
cat_score['score'] = cat_score.sum(axis=1)
cat_score.sort_values(by='score', ascending=False)[['score']]
# Out:
# Internal Country           score
# cat_name
# Finance             23175.355271
# Utilities           22761.358424
# Travel              19759.084892
# Food & Drink        13729.999521
# Healthcare/Fitness  10429.692656
# Education           10184.410434
# Navigation          10071.814819
# Medical              3743.369116
# Business             3528.573699
# Shopping              203.560662
# Lifestyle               0.988006
# News                    0.196468
# Reference               0.007584

# %%
subcat_score = df_subcat_scores.transpose().droplevel(0)
subcat_score['score'] = subcat_score.sum(axis=1)

creative_ui.df_to_sheet(subcat_score.sort_values(by='score', ascending=False)[['score']], sheet='SOURCE - Available SubCat Scored', index=True)
subcat_score.sort_values(by='score', ascending=False)[['score']]
# Out:
# Internal Country               score
# SubCat
# Productivity            17468.953174
# Personal Transport       8452.340051
# Maps                     8391.000552
# Travel Booking           7264.548127
# Delivery Service         7184.896037
# Health Self Management   6105.442941
# Cryptocurrency           4970.095600
# Government/COVID         4876.957668
# Job Search               3790.312150
# Service Provider         3199.496072
# Study Platform           3053.108348
# Restaurant Order         2511.630742
# Patient Platform         2139.999947
# Online Learning          1587.886485
# Reference                1551.311414
# Parking                  1406.285101
# Edutainment              1303.990570
# Travel Tools             1101.315994
# Learning Tools            807.589211
# eGov                      754.333952
# Payments                  544.815178
# Consumer Offers           287.698920
# Telemedicine              269.897129
# Excercise Locations       230.865524
# Clinic                    187.762512
# Student Platform          155.441522
# Pharmacy                  135.584419
# Health Reference           81.971342
# Consumer Deals             49.795602
# HR                         37.415471
# -                          15.239408
# Classroom                   2.596252
# Emergency                   0.941449

# %% [markdown]
# ### Importing the selected sub categories from creative.ui and scoring the customised category

# %%
df_custom = creative_ui.sheet_to_df(sheet="OUTPUT - Selected SubCat", index=False)
custom_list = df_custom['Selected_SubCat'].tolist()
digital_learning = custom_list
custom_cat = 'digital_learning'
digital_learning
# Out:
# ['Study Platform',
#  'Online Learning',
#  'Learning Tools',
#  'Student Platform',
#  '-',
#  'Classroom']

# %%
df_ranking_score = df_charts_ww_final.copy()
df_ranking_score = (
    df_ranking_score
    [['Internal Country','SubCat', 'internet_penetration' , 'unique_score', 'score_ranking','app_id']]
)
df_ranking_score['final_score'] = df_ranking_score['score_ranking'].fillna(0) * df_ranking_score['internet_penetration'].str.replace('%','').astype(float) / 100
df_ranking_score = df_ranking_score[df_ranking_score.final_score.notnull()]
df_ranking_score['custom_cat'] = df_ranking_score.SubCat.isin(custom_list)
df_custom_scores = df_ranking_score.groupby(['Internal Country', 'custom_cat']).agg('sum')[['final_score']].sort_values('final_score', ascending=False).unstack().droplevel(0, axis=1)
creative_ui.df_to_sheet(df_custom_scores.sort_values(by=True, ascending=False), sheet=f'SOURCE - {custom_cat} Scored', index=True, replace=True)
creative_ui.df_to_sheet(df_custom_scores.sort_values(by=True, ascending=False), sheet= 'SOURCE - Custom Scored', index=True, replace=True)

df_custom_scores.sort_values(by=True, ascending=False)
# Out:
# custom_cat              False        True
# Internal Country
# Sweden            2637.108597  424.436497
# Norway            3265.341093  423.799236
# Switzerland       2496.729473  272.310614
# USA               1825.340290  247.304726
# New Zealand       1757.617943  233.351231
# Finland           2146.437758  232.029099
# Denmark           2658.593907  231.407452
# Netherlands       2733.917073  183.152389
# Estonia           2478.570806  159.617967
# Saudi Arabia      2086.504835  154.060883
# Mexico            1304.355218  123.940410
# Philippines       1190.296949  123.453866
# Thailand          1357.945549  122.573079
# Germany           2303.576611  119.932204
# Hong Kong         2653.486103  110.257584
# Slovakia          2245.260690  109.094357
# South Korea       2718.287716  100.638475
# Portugal          2131.706045   98.539638
# Czechia           2151.473806   98.338177
# Qatar             1899.575050   95.616010
# Vietnam           1440.289165   94.994823
# Argentina         2180.847024   94.059078
# Greece            2120.216142   93.414181
# Chile             1973.116301   89.023423
# Colombia          1592.520744   86.266186
# Austria           2482.001165   85.215080
# Hungary           2069.149856   84.977352
# Romania           2015.686301   81.667629
# Indonesia         1083.340104   80.617894
# Singapore         2452.924340   78.966049
# Poland            2120.967264   77.874278
# Israel            2416.368598   73.413960
# South Africa      1397.909974   72.117314
# Lithuania         2328.598154   71.859306
# Australia         2284.868471   70.967427
# Ukraine           1692.667748   65.797500
# Malaysia          2032.866865   62.666492
# UAE               2335.712885   61.379101
# Ireland           2410.964167   59.376248
# Brazil            1932.579166   50.855412
# Egypt             1228.972495   48.555205
# Belgium           2445.656123   47.707022
# Turkey            2095.588264   38.874554
# Russia            2088.120174   34.973235
# Taiwan            1788.858290   30.142889
# Italy             1668.735569   29.055753
# Bulgaria          1630.214805   28.553652
# Spain             2303.101528   26.786001
# Canada            2419.008255   25.001128
# China             1660.780565   22.131698
# Japan             1866.927520   21.797149
# France            2368.044007   19.749387
# UK                2482.788205   16.573408
# Pakistan           375.329403   15.537733
# India              482.220997   11.164173
# Kenya              450.885675    5.486743
# Nigeria            205.598506    0.408873
